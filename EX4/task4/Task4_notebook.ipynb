# %%
from task4 import *

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Task 4: Chaotic dynamics
# ### Part 1: Logistic map $x_{n+1}=rx_n(1-x_n)$
# ### Zigzag trajectory plots on the visualized logistic map

# %%
logistic_map_vis(r = 0.8, x0 = 0.4, n = 20)
logistic_map_vis(r = 1.3, x0 = 0.4, n = 20)
logistic_map_vis(r = 2, x0 = 0.4, n = 20)
logistic_map_vis(r = 2.9, x0 = 0.4, n = 20)
logistic_map_vis(r = 3.3, x0 = 0.4, n = 20)
logistic_map_vis(r = 3.8, x0 = 0.4, n = 20)

# %% [markdown]
# ### Bifurcation diagram

# %%
logistic_map_bifurcation_vis(r_min=0, r_max=2, r_states=1000)
logistic_map_bifurcation_vis(r_min=2, r_max=4, r_states=1000)
logistic_map_bifurcation_vis(r_min=0, r_max=4, r_states=1000)

# %% [markdown]
# ### Part 2: Lorenz attractor
# ### Initial setting: σ = 10, β = 8/3, and ρ = 28

# %%
output1 = lorenz_attractor(xyz0 = [10,10,10], T_end = 1000, sigma=10, beta=8/3, rho=28)
output2 = lorenz_attractor(xyz0 = [10+1e-8,10,10], T_end = 1000, sigma=10, beta=8/3, rho=28)

# %%
plot_3d_traj(output1)

# %%
plot_3d_traj_compare(output1,output2)

# %% [markdown]
# ### Difference calculation in case: Initial setting: σ = 10, β = 8/3, and ρ = 28

# %%
difference_vis(output1, output2)
# Out:
#
#  The first time that difference is larger than 1 takes place at time point: 24.81

# %% [markdown]
# ### change the parameter ρ to the value 0.5
# ### Modified setting: σ = 10, β = 8/3, and ρ = 0.5

# %%
output1_rho5 = lorenz_attractor(xyz0 = [10,10,10], T_end = 1000, sigma=10, beta=8/3, rho=0.5)
output2_rho5 = lorenz_attractor(xyz0 = [10+1e-8,10+1e-8,10], T_end = 1000, sigma=10, beta=8/3, rho=0.5)

# %%
plot_3d_traj_rho5(output1_rho5)

# %%
plot_3d_traj_compare_rho5(output1_rho5,output2_rho5)

# %% [markdown]
# ### Difference calculation in case: Modified setting: σ = 10, β = 8/3, and ρ = 0.5

# %%
difference_vis(output1_rho5, output2_rho5)
