# %%
"""
Task 3:
1. Visualize the bifurcation of the system by plotting three phase diagrams at representative values of α.

"""
# Out:
# '\nTask 3:\n1. Visualize the bifurcation of the system by plotting three phase diagrams at representative values of α.\n\n'

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.integrate import solve_ivp

from utils import *

# %%
# plot the phase diagram a when alpha is -1.5
alpha = -1.5
plot_phase_diagrams(alpha)

# %%
# plot the phase diagram a when alpha is 0.0
alpha = 0.0
plot_phase_diagrams(alpha)

# %%
# plot the phase diagram a when alpha is 1.5
alpha = 1.5
plot_phase_diagrams(alpha)

# %%
"""
Task 3:

2. Numerically compute and visualize two orbits of the system.

"""
# Out:
# '\nTask 3:\n\n2. Numerically compute and visualize two orbits of the system.\n\n'

# %%
# plot the orbit when the initial point is (2, 0)
# Set the color of orbit as blue
y0 = (2, 0)
color = "blue"
compute_visualize_orbits(odefun, y0, color)

# %%
# plot the orbit when the initial point is (0.5, 0)
# Set the color of orbit as green
y0 = (0.5, 0)
color = "green"
compute_visualize_orbits(odefun, y0, color)

# %%
"""
Task 3:

3. Visualize the bifurcation surface of the cusp bifurcation in a 3D plot.

"""
# Out:
# '\nTask 3:\n\n3. Visualize the bifurcation surface of the cusp bifurcation in a 3D plot.\n\n'

# %%
# compute the values of alpha1_grid, alpha2_grid, x_grid
# show the 3D plot of the bifurcation surface from a default angle
alpha1_grid, alpha2_grid, x_grid = compute_bifurcation_params()
plot_bifurcation_surface(alpha1_grid, alpha2_grid, x_grid, None, None)

# %%
# show the 3D plot of the bifurcation surface from a angle (30, 120)
plot_bifurcation_surface(alpha1_grid, alpha2_grid, x_grid, 30, 120)
