# %%
from bifurcation_diagram import *

# %% [markdown]
# ### One experiment to find the steady states

# %%
x = Symbol('x')
alpha = 1
funtion_solution = 'alpha - x**2'
sol = solve(eval(funtion_solution), x)
print(sol)
# Out:
# [-1, 1]

# %% [markdown]
# ### 1. Producing the bifurcation diagram for alpha in [-1,1]  with funtion
# $$\dot x = \alpha - x^2$$

# %%
# take 1000 alpha as experiments data.
bifurcation_diagram('alpha - x**2', min_alpha=-1, max_alpha=1, alpha_gap=0.001)

# %% [markdown]
# ### 2. Producing the bifurcation diagram for alpha in [-10,10]  with funtion
# $$\dot x = \alpha - 2x^2 - 3$$

# %%
# take 1000 alpha as experiments data.
bifurcation_diagram('alpha - 2*(x**2) - 3', min_alpha=-10, max_alpha=10, alpha_gap=0.001)
